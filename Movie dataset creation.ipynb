# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import requests
from bs4 import BeautifulSoup as bs

# %%
def get_content_value (row):
    if row.find_all('li'):
        return [li.get_text(' ', strip = True).replace('\xa0',' ') for li in row.find_all('li')]
    elif row.find('br'):
        return [text for text in row.stripped_strings]  
    else:
        return row.find('td').get_text(' ', strip = True).replace('\xa0',' ')
    
   

#  Removing the reference tagsd
def clean_tag(soup):    
    for tag in soup.find_all(['sup','span']):
        tag.decompose()



def grab_info_box(movie_url):
    
    r = requests.get(movie_url)
    webpage = bs (r.content)

    clean_tag(webpage)
    
    info_box = webpage.find(class_ = 'infobox vevent')
    rows = info_box.find_all('tr')
  
    movie_info = {}
    for index,value in enumerate(rows):
        if index == 0:
            movie_info ['title'] = value.find('th').get_text(' ', strip = True)
        else:
            header = value.find('th')
            if header:
                caption = value.find('th').get_text(' ', strip = True)
                content = get_content_value (value)
                movie_info[caption] = content
            
    return movie_info

# %%
# Now we want to get the link of all movies in URL = "https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films"

disney_films = requests.get ('https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')
disney_movies = bs (disney_films.content)
movies = disney_movies.select('.wikitable.sortable i a')

base_path = 'https://en.wikipedia.org/'
movie_list = []
for index, movie in enumerate(movies):
    try:
        link = movie['href']
        full_path = base_path + link
        title = movie['title']
        movie_list.append(grab_info_box(full_path))
    except:
        continue

# %%
        # Saving json
import json

with open('disney_movie_df.json', 'w', encoding='utf-8') as f:
    json.dump(movie_list, f,ensure_ascii = False, indent =2)

# %% [markdown]
# Now, we saved our data and we are doing some more cleaning as much as possible

# %%
# loading data
import json
with open('disney_movie_df.json', encoding='utf-8') as f:
    data = json.load(f)

# %% [markdown]
#  Some sub tasks to do:
#  ~~ 1- clean up the refrences [1], [2], etc ~~
#  ~~ 2- convert running time to int ~~
#  3- convert date into datetime object
#  ~~ 4- split up the long string ~~
#  ~~5- convert budget and box office to numbers ~~

# %%
run_time = [film.get('Running time', 'N/A') for film in data]

# %%
def running_time_to_int(running_time) :
    
    if isinstance (running_time, list):
        return int (running_time[1].split(' ')[0])
    elif running_time == 'N/A':
        return None
    else:
        return int (running_time.split(' ')[0])

# %%
run_time_int = [running_time_to_int(times) for times in run_time]

# %%
for i, movies in enumerate(data):
    movies ['run time int'] = run_time_int[i]

# %%
##  5- convert budget and box office to numbers 

[t.get('Budget', 'N/A') for t in data]
# Out:
# ['$1.5 million',
#  '$2.6 million',
#  '$2.28 million',
#  '$600,000',
#  '$950,000',
#  '$858,000',
#  'N/A',
#  '$788,000',
#  'N/A',
#  '$1.35 million',
#  '$2.125 million',
#  'N/A',
#  '$1.5 million',
#  '$1.5 million',
#  'N/A',
#  '$2.2 million',
#  '$1.8 million',
#  '$3 million',
#  'N/A',
#  '$4 million',
#  '$2 million',
#  '$300,000',
#  '$1.8 million',
#  'N/A',
#  '$5 million',
#  'N/A',
#  '$4 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$700,000',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$6 million',
#  'under $1 million or $1,250,000',
#  'N/A',
#  '$2 million',
#  'N/A',
#  'N/A',
#  '$2.5 million',
#  'N/A',
#  'N/A',
#  '$4 million',
#  '$3.6 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$3 million',
#  'N/A',
#  '$3 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$3 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$4.4–6 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$4 million',
#  'N/A',
#  '$5 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$5 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$4 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$6.3 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$5 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$8 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'AU$1 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$5 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$7.5 million',
#  'N/A',
#  '$10 million',
#  'N/A',
#  'N/A',
#  '$3.5 to 4 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$5.25 million',
#  '$20 million',
#  '$4.5 million',
#  '$9 million',
#  'N/A',
#  '$6-8 million',
#  '$20 million',
#  'N/A',
#  'N/A',
#  '$18 million',
#  '$12 million',
#  '$14 million',
#  '$10 million',
#  '$17 million',
#  '$5 million',
#  '$8 million',
#  '$20 million',
#  '$11 million',
#  '$28 million',
#  '$44 million',
#  'N/A',
#  '$7.5 million',
#  '$14 million',
#  '$9 million',
#  'N/A',
#  'A$8.7 million',
#  '$31 million',
#  '$18 million',
#  '$5 million',
#  '$40 million',
#  '$20 million',
#  'N/A',
#  '$14 million',
#  '60 million Norwegian Kroner (around $8.7 million in 1989)',
#  'N/A',
#  '$35-40 million',
#  '$25 million',
#  '$15 million',
#  '$32 million',
#  '$14 million',
#  '$28 million',
#  '$12 million',
#  'N/A',
#  'N/A',
#  '$11 million',
#  '$28 million',
#  '$17 million',
#  '$30 million',
#  'N/A',
#  '$13 million',
#  'N/A',
#  'N/A',
#  '$5 million',
#  '$45 million',
#  '$31 million',
#  'N/A',
#  '$22 million',
#  '$30 million',
#  'N/A',
#  'N/A',
#  '$22 million',
#  ['Budget', '$32 million', '(estimated)'],
#  '$18 million',
#  '$55 million',
#  '$24 million',
#  '$15 million',
#  '$12 million',
#  'N/A',
#  '$30 million',
#  'N/A',
#  '$31 million',
#  'N/A',
#  '$38 million',
#  '$70 million',
#  'N/A',
#  '$15 million',
#  'N/A',
#  '$67 million',
#  'N/A',
#  '$32 million',
#  '$7 million',
#  '$85 million',
#  '$55 million',
#  '$3 million',
#  'N/A',
#  '$16 million',
#  'N/A',
#  '$80 million',
#  '$30 million',
#  'N/A',
#  '$24 million',
#  '$90 million',
#  '$15 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$30 million',
#  '$40–120 million',
#  '$90 million',
#  '$65 million',
#  '$5 million',
#  'N/A',
#  '$130 million',
#  '$75–90 million',
#  'N/A',
#  '$10 million',
#  'N/A',
#  '$90 million',
#  '$80–85 million',
#  '$15 million –$30 million',
#  'N/A',
#  '$4,000,000 (estimated)',
#  '$127.5 million',
#  '$65 million',
#  'N/A',
#  'N/A',
#  '$30 million',
#  '$85 million',
#  '$100 million',
#  '$23 million',
#  'N/A',
#  '$90–120 million',
#  '$26 million',
#  '$25 million',
#  '$115 million',
#  'N/A',
#  '$33 million',
#  '$20 million',
#  '$5 million',
#  'N/A',
#  '$22 million',
#  '$80 million',
#  'N/A',
#  '$35 million',
#  'N/A',
#  '$15 million',
#  '$65 million',
#  '$140 million',
#  'N/A',
#  '$20 million',
#  '$12 million',
#  '$46 million',
#  '$13 million',
#  '$20 million',
#  '$17 million',
#  'N/A',
#  '$94 million',
#  '$140 million',
#  '$26 million',
#  'N/A',
#  'N/A',
#  '$46 million',
#  '$90 million',
#  'N/A',
#  '$10 million',
#  '$28 million',
#  'N/A',
#  '$15 million',
#  'N/A',
#  '$110 million',
#  'N/A',
#  '$110 million',
#  'N/A',
#  '$45 million',
#  'N/A',
#  '$92–145 million',
#  'N/A',
#  '$100 million',
#  'N/A',
#  'N/A',
#  '$20 million',
#  '$56 million',
#  '$25 million',
#  'N/A',
#  '$50 million',
#  '$35 million',
#  '$35 million',
#  'N/A',
#  'N/A',
#  '$25 million',
#  '$150 million',
#  '$180 million',
#  'N/A',
#  '$30 million',
#  '$1 million',
#  'N/A',
#  '$40 million',
#  '$50 million',
#  '$80 million',
#  '$120 million',
#  'N/A',
#  '$225 million',
#  '$30 million',
#  'N/A',
#  '$24 million',
#  'N/A',
#  'N/A',
#  '$8 million',
#  '$17 million',
#  '$150 million',
#  '$300 million',
#  '$150 million',
#  'N/A',
#  '$25 million',
#  'N/A',
#  '$22 million',
#  '$85 million',
#  '$130 million',
#  '$7 million',
#  '$25 million',
#  '$225 million',
#  '$180 million',
#  'N/A',
#  '$20 million',
#  'N/A',
#  '$11 million',
#  'N/A',
#  '$50 million',
#  '$150 million',
#  '$80 million',
#  'N/A',
#  '$50 million',
#  '$30 million',
#  '$47 million',
#  'N/A',
#  '$175 million',
#  'N/A',
#  '$150 million',
#  'N/A',
#  '$30—$35 million',
#  '$8 million ( ₽ 350 million)',
#  '$175–200 million',
#  '$35 million',
#  '$105 million',
#  '$150 –$200 million',
#  'N/A',
#  '$80 million',
#  '$150–200 million',
#  '$200 million',
#  '$150 million',
#  'N/A',
#  '$30—$35 million',
#  '$35 million',
#  'N/A',
#  '$260 million',
#  '$170 million',
#  '',
#  'N/A',
#  'N/A',
#  '$150 million',
#  'N/A',
#  '$5 million',
#  '$8 million',
#  ['$410.6 million (gross)', '$378.5 million (net)'],
#  '$200 million',
#  '$30 million',
#  'N/A',
#  '$45 million',
#  'N/A',
#  ['$306.6 million (gross)', '$263.7 million (net)'],
#  '$5 million',
#  'N/A',
#  '$185 million',
#  '$25 million',
#  'N/A',
#  '$39 million',
#  '$30—35 million',
#  '$165 million',
#  '$215 million',
#  'N/A',
#  '$200 million',
#  '$225–250 million',
#  '$50 million',
#  'N/A',
#  '$150 million',
#  '$35 million',
#  '$50 million',
#  'N/A',
#  '$5 million',
#  '$25 million',
#  '$180–263 million',
#  '$50 million',
#  '(US$2.9 million)',
#  '$28 million',
#  '$165 million',
#  '$50 million',
#  '$17 million',
#  'N/A',
#  '$84.21–95 million',
#  '$5–10 million',
#  '$180–190 million',
#  '$175 million',
#  '',
#  '$175–200 million',
#  '$70–80 million',
#  '$150 million',
#  '$175–177 million',
#  'N/A',
#  '$170 million',
#  '$200 million',
#  '$140 million',
#  '$65 million',
#  '$15 million',
#  '$150–175 million',
#  '',
#  '$8 million',
#  '$160–255 million',
#  '$5–10 million',
#  '$230–320 million',
#  '$175 million',
#  'N/A',
#  '131 crore',
#  ['Budget', '~$8 million', '₽', '370 million'],
#  '$175–225 million',
#  '$100–130 million',
#  '$200 million',
#  '$65-70 million',
#  '$120–133 million',
#  '$175 million',
#  '$130 million',
#  '$170 million',
#  'N/A',
#  '$183 million',
#  '$200 million',
#  '$250–260 million',
#  '$185 million',
#  '$60 million',
#  'N/A',
#  '$150 million',
#  '$40 million',
#  '$42 million',
#  '$175–200 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$125 million',
#  '$12.5 million (stage production)',
#  'N/A',
#  '$24 million',
#  'N/A',
#  '$200 million',
#  'N/A',
#  '$26 million',
#  '$150 million',
#  '₽650 million',
#  'N/A',
#  '$116 million+',
#  '$100–200 million',
#  'N/A',
#  '$200 million',
#  '$120–150 million',
#  'N/A',
#  '₽454 million',
#  'N/A',
#  '$175 million',
#  'N/A',
#  '$36 million',
#  'N/A',
#  '~$70 million',
#  'N/A',
#  '$200 million',
#  'N/A',
#  '$150 million',
#  '$40 million',
#  'N/A',
#  '$135–180 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$53.4 million',
#  '$250 million',
#  '$200 million',
#  '$295 million',
#  '$157.8 million',
#  'N/A',
#  'N/A',
#  '$175 million',
#  '$250–260 million',
#  'N/A',
#  '$28 million',
#  '$858,000',
#  'N/A',
#  '$9 million',
#  '$85 million',
#  '$70 million',
#  '$75–90 million',
#  'N/A',
#  '$150–175 million',
#  '$130 million',
#  'N/A',
#  '$18 million or $25 million',
#  'N/A',
#  '$4 million',
#  ['Budget', '$15,000,000', '(1 film)'],
#  '$11—15 million',
#  'N/A',
#  '$35-40 million',
#  '$150 million']

# %%
import re

amounts = r"thousand|million|billion"
number = r"\d+(,\d{3})*\.*\d*"

word_re = rf"\${number}(-|\sto\s|–)?({number})?\s({amounts})"
value_re = rf"\${number}"

def word_to_value(word):
    value_dict = {"thousand": 1000, "million": 1000000, "billion": 1000000000}
    return value_dict[word]

def parse_word_syntax(string):
    value_string = re.search(number, string).group()
    value = float(value_string.replace(",", ""))
    word = re.search(amounts, string, flags=re.I).group().lower()
    word_value = word_to_value(word)
    return value*word_value

def parse_value_syntax(string):
    value_string = re.search(number, string).group()
    value = float(value_string.replace(",", ""))
    return value

'''
money_conversion("$12.2 million") --> 12200000 ## Word syntax
money_conversion("$790,000") --> 790000        ## Value syntax
'''
def money_conversion(money):
    if money == "N/A":
        return None

    if isinstance(money, list):
        money = money[0]
        
    word_syntax = re.search(word_re, money, flags=re.I)
    value_syntax = re.search(value_re, money)

    if word_syntax:
        return parse_word_syntax(word_syntax.group())

    elif value_syntax:
        return parse_value_syntax(value_syntax.group())

    else:
        return None

# %%
for movie in data:
    movie['budget (int)'] = money_conversion(movie.get('Budget', 'N/A'))
    movie['Box office (int)'] = money_conversion(movie.get('Box office', 'N/A'))

# %%
dates = [movie.get('Release dates', 'N/A') for movie in data]
dates
# Out:
# [['December 21, 1937 ( Carthay Circle Theatre )',
#   'February 4, 1938 (United States)'],
#  ['February 7, 1940 ( Center Theatre )', 'February 23, 1940 (United States)'],
#  'N/A',
#  'N/A',
#  ['October 23, 1941 (New York City)', 'October 31, 1941 (U.S.)'],
#  ['August 9, 1942 ( London )', 'August 21, 1942 (United States)'],
#  ['August 24, 1942 (Rio de Janeiro)',
#   'February 6, 1943 (Boston)',
#   'February 19, 1943 (United States)'],
#  'N/A',
#  ['December 21, 1944 (Mexico City)', 'February 3, 1945 (United States)'],
#  ['April 20, 1946 (New York City)', 'August 15, 1946 (United States)'],
#  ['November 12, 1946 (premiere)', 'November 20, 1946'],
#  'N/A',
#  'N/A',
#  ['November 29, 1948 (Chicago)', 'January 19, 1949 (Indianapolis)'],
#  'N/A',
#  ['February 15, 1950 (Boston)', 'March 4, 1950 (United States)'],
#  ['June 22, 1950 (London)', 'July 29, 1950 (United States)', 'July 19, 1950'],
#  ['July 26, 1951 (London)',
#   'July 28, 1951 (New York City)',
#   'September 14, 1951 (United States)'],
#  ['13 March 1952 (London)', '26 June 1952 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['26 October 1953 (London)', '27 February 1954 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 24, 1959 (Dublin)', 'June 26, 1959 (Los Angeles)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 1960 ( Berlin )', 'August 10, 1960 (US)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 14, 1962 (London, premiere)', 'December 19, 1962 (US)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 12, 1963 (London)', 'December 25, 1963 (United States)'],
#  'N/A',
#  'N/A',
#  ['11 December 1963 ( New York City )', '4 June 1964 (U.S.)'],
#  'N/A',
#  ['August 27, 1964 ( Los Angeles )', 'September 24, 1964 ( New York City )'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['February 4, 1966 (premiere)', 'February 16, 1966 (United States)'],
#  ['June 29, 1966 (Premiere)', 'July 29, 1966 (U.S.)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 23, 1967', 'November 30, 1967'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 24, 1968 (limited)', 'March 13, 1969 (wide)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 11, 1970 (premiere)', 'December 24, 1970 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['October 7, 1971 (United Kingdom)', 'December 13, 1971 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 17, 1976 (Los Angeles)', 'January 21, 1977 (United States)'],
#  ['Release dates', 'May 26, 1976', '(UK)', 'March 11, 1977', '(US)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['Release dates', 'July 19, 1979 (London)', 'August 3, 1979 (Los Angeles)'],
#  ['December 18, 1979 (United Kingdom)', 'December 21, 1979 (United States)'],
#  'N/A',
#  ['April 17, 1980 (New York City)', 'October 9, 1981 (U.S.)'],
#  'N/A',
#  'N/A',
#  ['December 6, 1980 ( Los Angeles )', 'December 12, 1980 ( United States )'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['Release dates', 'October 7, 1983 (limited)', 'January 27, 1984 (release)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['3 October 1990'],
#  'N/A',
#  'N/A',
#  ['September 29, 1991 ( NYFF )',
#   'November 13, 1991 ( El Capitan Theatre )',
#   'November 22, 1991 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 5, 1994 ( Hollywood )', 'November 11, 1994 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 10, 1995 ( Central Park )', 'June 16, 1995 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['January 22, 1995 ( Sundance Film Festival )', 'October 20, 1995 (U.S.)'],
#  ['November 19, 1995 ( El Capitan Theatre )',
#   'November 22, 1995 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['April 12, 1996 (United States)', 'August 2, 1996 (United Kingdom)'],
#  ['June 19, 1996 (Louisiana Superdome)', 'June 21, 1996 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 18, 1996 (New York City)',
#   'November 24, 1996 (Hollywood)',
#   'November 27, 1996 (United States)'],
#  'N/A',
#  ['March 7, 1997 (US)', 'August 5, 1997 (France)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 16, 1997 ( Pennsylvania )', 'November 26, 1997 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 5, 1998 ( Hollywood Bowl )', 'June 19, 1998 (United States)'],
#  ['July 20, 1998 (Los Angeles)', 'July 29, 1998 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 14, 1998 ( El Capitan Theatre )',
#   'November 20, 1998 (North America)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['Release dates', 'September 1998', '(Telluride Film Festival)'],
#  ['June 12, 1999 ( El Capitan Theatre )', 'June 16, 1999 (United States)'],
#  'N/A',
#  'N/A',
#  ['May 21, 1999', 'October 15, 1999 (United States)'],
#  'N/A',
#  ['November 13, 1999 ( El Capitan Theatre )',
#   'November 24, 1999 (United States)'],
#  ['December 17, 1999 ( Carnegie Hall )',
#   'January 1, 2000 ( IMAX )',
#   'June 16, 2000 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 13, 2000 ( El Capitan Theatre )', 'May 19, 2000 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 10, 2000 ( El Capitan Theatre )',
#   'December 15, 2000 (United States)'],
#  ['February 10, 2001 (premiere)', 'February 16, 2001 (United States)'],
#  'N/A',
#  ['June 3, 2001 ( El Capitan Theatre )', 'June 15, 2001 (United States)'],
#  ['July 29, 2001 ( El Capitan Theatre )', 'August 3, 2001 (United States)'],
#  'N/A',
#  ['October 28, 2001 ( El Capitan Theatre )',
#   'November 2, 2001 (United States)'],
#  'N/A',
#  'N/A',
#  ['February 10, 2002 ( New York City )', 'February 15, 2002 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 16, 2002 ( El Capitan Theatre )', 'June 21, 2002'],
#  'N/A',
#  ['July 21, 2002', 'July 26, 2002'],
#  'N/A',
#  'N/A',
#  ['October 23, 2002 ( Los Angeles )', 'November 1, 2002 (United States)'],
#  ['November 6, 2002 ( Paris )', 'November 27, 2002 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 16, 2003 (Premiere)',
#   'April 22, 2003 (United States)',
#   'July 2, 2003 ( Manila , Philippines)',
#   'July 29, 2003 (Disney DVD and video)'],
#  ['March 31, 2003 (premiere)', 'April 11, 2003 (limited)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 18, 2003 ( Los Angeles )', 'May 30, 2003 (United States)'],
#  ['June 28, 2003 ( Disneyland Resort )', 'July 9, 2003 (United States)'],
#  ['August 4, 2003 ( Los Angeles )', 'August 6, 2003 (United States)'],
#  'N/A',
#  'N/A',
#  ['October 20, 2003 ( New Amsterdam Theatre )',
#   'November 1, 2003 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 21, 2004 ( El Capitan Theatre )', 'April 2, 2004 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['October 24, 2004 ( El Capitan Theatre )',
#   'November 5, 2004 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 3, 2004 (Italy)', 'February 1, 2005 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 10, 2005 ( Las Vegas Motor Speedway )',
#   'June 22, 2005 (United States)'],
#  'N/A',
#  ['March 25, 2005 (UK)', 'August 19, 2005 (US)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['October 30, 2005 ( El Capitan Theatre )',
#   'November 4, 2005 (United States)'],
#  ['7 December 2005 ( Royal Film Performance )',
#   '8 December 2005 (United Kingdom)',
#   '9 December 2005 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['January 26, 2006 (Argentina)', 'February 7, 2006 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ["May 26, 2006 ( Lowe's Motor Speedway )", 'June 9, 2006 (United States)'],
#  ['June 23, 2006', 'June 27, 2006'],
#  ['June 16, 2006 ( Disneyland Resort )', 'July 7, 2006 (United  States)'],
#  'N/A',
#  'N/A',
#  ['October 13, 1993 (limited)', 'October 29, 1993 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 23, 2007 (United Kingdom)', 'March 30, 2007 (United States)'],
#  ['May 19, 2007 ( Disneyland Resort )', 'May 25, 2007 (United States)'],
#  ['June 22, 2007 ( Kodak Theatre )', 'June 29, 2007 (United States)'],
#  ['June 29, 2007 (China)', 'January 26, 2009 (United States)'],
#  'N/A',
#  'N/A',
#  ['September 23, 2007 ( Hollywood )', 'September 28, 2007 (United States)'],
#  ['October 20, 2007 ( London )', 'November 21, 2007 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 7, 2008 ( New York City )',
#   'May 16, 2008 (United States)',
#   'June 26, 2008 (United Kingdom)'],
#  ['June 23, 2008 ( Greek Theatre )', 'June 27, 2008 (United States)'],
#  'N/A',
#  ['September 18, 2008 ( El Capitan Theatre )',
#   'October 3, 2008 (United States)'],
#  'N/A',
#  ['October 17, 2008 (London)', 'October 24, 2008 (United States)'],
#  ['23 October 2008 (Kuwait)', '24 October 2008 (India and United States)'],
#  'N/A',
#  ['November 17, 2008 ( El Capitan Theatre )',
#   'November 21, 2008 (United States)'],
#  'N/A',
#  'N/A',
#  ['March 11, 2009 (Egypt)', 'March 13, 2009 (United States)'],
#  'N/A',
#  ['10 October 2007 (France)',
#   '16 November 2007 (United Kingdom)',
#   '12 January 2008 (Germany)',
#   '22 April 2009 (United States)'],
#  ['April 24, 2009 (San Francisco International Film Festival)',
#   'May 22, 2009 (United States)'],
#  ['May 13, 2009 ( Cannes )', 'May 29, 2009 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 5, 2009 (Japan)',
#   'October 27, 2009 (United States)',
#   'February 15, 2010 (Hindi)'],
#  'N/A',
#  ['November 3, 2009 ( London )', 'November 6, 2009 (United States)'],
#  'N/A',
#  ['November 25, 2009 ( Los Angeles and New York City )',
#   'December 11, 2009 (United States)'],
#  ['February 25, 2010 ( Odeon Leicester Square )',
#   'March 5, 2010 (United States)'],
#  ['September 6, 2009 ( Telluride Film Festival )', 'March 26, 2010'],
#  ['October 17, 2009 ( Tokyo International Film Festival )',
#   'January 24, 2010 (France)'],
#  ['May 9, 2010 (London premiere)', 'May 28, 2010 (United States)'],
#  ['June 12, 2010 ( Taormina Film Fest )', 'June 18, 2010 (United States)'],
#  ['July 8, 2010 (Fantasia Film Festival)', 'July 14, 2010'],
#  ['26 October 2008 ( France )', '29 September 2009 ( United Kingdom )'],
#  ['August 13, 2010 (United Kingdom)', 'September 21, 2010 (United States)'],
#  ['September 30, 2010 ( Hollywood )', 'October 8, 2010 (United States)'],
#  'N/A',
#  ['November 14, 2010 ( El Capitan Theatre )',
#   'November 24, 2010 (United States)'],
#  ['November 30, 2010 (Tokyo)', 'December 17, 2010 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 6, 2011 ( El Capitan Theatre )', 'March 11, 2011 (United States)'],
#  'N/A',
#  ['April 22, 2011 (United States)',
#   'February 1, 2012 (France)',
#   'April 27, 2012 (United Kingdom)'],
#  'N/A',
#  ['May 7, 2011 ( Disneyland Resort )', 'May 20, 2011 (United States)'],
#  ['June 18, 2011 (Hollywood)', 'June 24, 2011 (United States)'],
#  ['April 6, 2011 (Belgium)', 'July 15, 2011 (United States)'],
#  'N/A',
#  ['November 4, 2011 (Savannah Film Festival)',
#   'November 23, 2011 (United States)'],
#  'N/A',
#  ['February 22, 2012 ( Los Angeles )', 'March 9, 2012 (United States)'],
#  ['April 20, 2012 (United States)',
#   'February 20, 2013 (France)',
#   'May 3, 2013 (United Kingdom)'],
#  'N/A',
#  ['June 10, 2012 ( SIFF )', 'June 22, 2012 (United States)'],
#  'N/A',
#  'N/A',
#  ['September 20, 2012 ( Fantastic Fest )',
#   'October 5, 2012 ( United States )'],
#  ['August 16, 2012 (Ukraine)',
#   'August 31, 2012 (United States (limited))',
#   'October 23, 2012 (DVD release)'],
#  ['October 29, 2012 ( El Capitan Theatre )',
#   'November 2, 2012 (United States)'],
#  ['February 14, 2013 ( El Capitan Theatre )', 'March 8, 2013 (United States)'],
#  ['16 March 2011 (France)', '16 April 2013 (United States)'],
#  ['June 5, 2013 ( BFI Southbank )', 'June 21, 2013 (United States)'],
#  ['June 22, 2013 ( Hyperion Theatre )', 'July 3, 2013 (United States)'],
#  ['August 2, 2013 ( EAA AirVenture Oshkosh )',
#   'August 9, 2013 (United States)'],
#  'N/A',
#  ['November 19, 2013 ( El Capitan Theatre )',
#   'November 27, 2013 (United States)'],
#  ['October 20, 2013 ( BFI London Film Festival )',
#   'November 29, 2013 (United Kingdom)',
#   'December 13, 2013 (United States)',
#   'January 9, 2014 (Australia)'],
#  ['March 11, 2014 ( El Capitan Theatre )', 'March 21, 2014 (United States)'],
#  ['February 13, 2014 (Denmark)', 'April 1, 2014 (United States)'],
#  'N/A',
#  ['May 6, 2014 ( El Capitan Theatre )', 'May 16, 2014 (United States)'],
#  ['May 28, 2014 ( El Capitan Theatre )', 'May 30, 2014 (United States)'],
#  ['July 15, 2014 ( El Capitan Theatre )', 'July 18, 2014 (United States)'],
#  'N/A',
#  ['October 6, 2014 ( El Capitan Theatre )',
#   'October 10, 2014 (United States)'],
#  ['October 23, 2014 ( Tokyo International Film Festival )',
#   'October 31, 2014 ( Abu Dhabi Film Festival )',
#   'November 7, 2014 (United States)'],
#  ['December 8, 2014 ( Ziegfeld Theatre )',
#   'December 25, 2014 (United States)'],
#  ['February 9, 2015 ( Hollywood )', 'February 20, 2015 (United States)'],
#  ['December 12, 2014 (United Kingdom)', 'January 30, 2015 (United States)'],
#  ['February 13, 2015 ( Berlinale )',
#   'March 13, 2015 (United States)',
#   'March 27, 2015 (United Kingdom)'],
#  'N/A',
#  ['May 9, 2015 ( Disneyland )', 'May 22, 2015 (United States)'],
#  ['May 18, 2015 ( Cannes )', 'June 19, 2015 (United States)'],
#  'N/A',
#  ['November 10, 2015 ( Paris )', 'November 25, 2015 (United States)'],
#  ['January 25, 2016 ( TCL Chinese Theatre )',
#   'January 29, 2016 (United States)'],
#  ['February 13, 2016 (Belgium)', 'March 4, 2016 (United States)'],
#  ['April 4, 2016 ( El Capitan Theatre )', 'April 15, 2016 (United States)'],
#  ['April 23, 2016 (Amsterdam)',
#   'May 6, 2016 (Spain)',
#   'May 12, 2016 (Italy)',
#   'June 2, 2016 (Argentina)'],
#  ['May 10, 2016 ( London )', 'May 27, 2016 (United States)'],
#  ['June 8, 2016 ( El Capitan Theatre )', 'June 17, 2016 (United States)'],
#  ['May 14, 2016 ( Cannes )',
#   'July 1, 2016 (United States)',
#   'July 22, 2016 (United Kingdom)',
#   'July 29, 2016 (India)'],
#  ['August 8, 2016 ( El Capitan Theatre )', 'August 12, 2016 (United States)'],
#  ['September 10, 2016 ( TIFF )', 'September 23, 2016 (United States)'],
#  ['November 14, 2016 ( AFI Fest )', 'November 23, 2016 (United States)'],
#  ['21 December 2016 (United States)', '23 December 2016 (India)'],
#  ['26 January 2005 (France)', '24 June 2005 (United States)'],
#  ['February 23, 2017 ( Spencer House )', 'March 17, 2017 (United States)'],
#  ['August 12, 2016 (China)',
#   'April 21, 2017 (United States)',
#   'August 23, 2017 (France)'],
#  ['May 11, 2017 ( Shanghai Disney Resort )', 'May 26, 2017 (United States)'],
#  ['May 23, 2017 ( Kannapolis )', 'June 16, 2017 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['October 20, 2017 ( Morelia )', 'November 22, 2017 (United States)'],
#  ['February 26, 2018 ( El Capitan Theatre )', 'March 9, 2018 (United States)'],
#  ['June 5, 2018 ( Los Angeles )', 'June 15, 2018 (United States)'],
#  ['July 30, 2018 ( Burbank )', 'August 3, 2018 (United States)'],
#  ['October 29, 2018 ( Dolby Theatre )', 'November 2, 2018 (United States)'],
#  ['November 5, 2018 ( El Capitan Theatre )',
#   'November 21, 2018 (United States)'],
#  ['November 29, 2018 ( Dolby Theatre )', 'December 19, 2018 (United States)'],
#  ['March 11, 2019 ( Los Angeles )', 'March 29, 2019 (United States)'],
#  'N/A',
#  ['May 8, 2019 ( Grand Rex )', 'May 24, 2019 (United States)'],
#  ['June 11, 2019 ( El Capitan Theatre )', 'June 21, 2019 (United States)'],
#  ['July 9, 2019 ( Hollywood )', 'July 19, 2019 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 7, 2019 ( Dolby Theatre )', 'November 22, 2019 (United States)'],
#  'N/A',
#  ['January 25, 2020 ( Sundance )', 'February 7, 2020 ( Disney+ )'],
#  ['February 21, 2020 ( Berlinale )', 'March 6, 2020 (United States)'],
#  'N/A',
#  ['March 28, 2018 (France)', 'April 3, 2020 ( Disney+ )'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 9, 2020 ( Dolby Theatre )', 'September 4, 2020 (United States)'],
#  'N/A',
#  'N/A',
#  ['October 11, 2020 ( BFI Fest )', 'December 25, 2020 (United States)'],
#  ['December 24, 2020 (United States)', 'January 1, 2021 ( Russia )'],
#  'N/A',
#  'N/A',
#  ['May 18, 2021 ( El Capitan Theatre )', 'May 28, 2021 (United States)'],
#  ['June 13, 2021 ( Aquarium of Genoa )', 'June 18, 2021 (United States)'],
#  ['July 24, 2021 ( Disneyland Resort )', 'July 30, 2021 (United States)'],
#  ['November 3, 2021 ( El Capitan Theatre )',
#   'November 24, 2021 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['March 1, 2022 ( El Capitan Theatre )', 'March 11, 2022 (United States)'],
#  ['March 16, 2022 ( El Capitan Theatre )', 'March 18, 2022 (United States)'],
#  ['March 15, 2022 ( El Capitan Theatre )', 'April 1, 2022 (United States)'],
#  'N/A',
#  ['May 16, 2022 ( Hollywood, California )', 'May 20, 2022 ( Disney+ )'],
#  ['May 23, 2022 ( El Capitan Theatre )', 'June 3, 2022 (United States)'],
#  ['June 8, 2022 ( El Capitan Theatre )', 'June 17, 2022 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['November 16, 2022 ( El Capitan Theatre )',
#   'November 18, 2022 (United States)'],
#  ['November 15, 2022 ( El Capitan Theatre )',
#   'November 23, 2022 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 8, 2023 ( Dolby Theatre )', 'May 26, 2023 (United States)'],
#  ['May 27, 2023 ( Cannes )', 'June 16, 2023 (United States)'],
#  ['May 18, 2023 ( Cannes )', 'June 30, 2023 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['May 18, 2015 ( Cannes )', 'June 19, 2015 (United States)'],
#  ['July 9, 2019 ( Hollywood )', 'July 19, 2019 (United States)'],
#  'N/A',
#  ['October 6, 2014 ( El Capitan Theatre )',
#   'October 10, 2014 (United States)'],
#  ['August 9, 1942 ( London )', 'August 21, 1942 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  ['June 19, 1996 (Louisiana Superdome)', 'June 21, 1996 (United States)'],
#  'N/A',
#  'N/A',
#  ['November 14, 2016 ( AFI Fest )', 'November 23, 2016 (United States)'],
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  ['December 11, 1970 (premiere)', 'December 24, 1970 (United States)'],
#  'N/A',
#  'N/A',
#  ['Release dates',
#   '1',
#   ': October\xa028,\xa02008',
#   '2',
#   ':',
#   '3',
#   ':',
#   '4',
#   ':',
#   '5',
#   ':',
#   '6',
#   ':'],
#  'N/A',
#  ['February 13, 2016 (Belgium)', 'March 4, 2016 (United States)']]

# %%
from datetime import datetime

def clean_date (date):
    return date.split('(')[0].strip()


def date_conversion(date):
    if isinstance(date, list):
        date = date[0]
    
    if date == 'N/A':
        return None
    
    date_str = clean_date(date)
    print(date_str)

    fmts = ['%B %d, %Y', '%d %B %Y'] 

    for fmt in fmts:
        try:
            return datetime.strptime(date_str, fmt)
        except:
            pass

# %%
for date in dates:
    print (date_conversion(date))
    print()
# Out:
# December 21, 1937
# 1937-12-21 00:00:00
#
# February 7, 1940
# 1940-02-07 00:00:00
#
# None
#
# None
#
# October 23, 1941
# 1941-10-23 00:00:00
#
# August 9, 1942
# 1942-08-09 00:00:00
#
# August 24, 1942
# 1942-08-24 00:00:00
#
# None
#
# December 21, 1944
# 1944-12-21 00:00:00
#
# April 20, 1946
# 1946-04-20 00:00:00
#
# November 12, 1946
# 1946-11-12 00:00:00
#
# None
#
# None
#
# November 29, 1948
# 1948-11-29 00:00:00
#
# None
#
# February 15, 1950
# 1950-02-15 00:00:00
#
# June 22, 1950
# 1950-06-22 00:00:00
#
# July 26, 1951
# 1951-07-26 00:00:00
#
# 13 March 1952
# 1952-03-13 00:00:00
#
# None
#
# None
#
# None
#
# 26 October 1953
# 1953-10-26 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# June 24, 1959
# 1959-06-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# June 1960
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# November 14, 1962
# 1962-11-14 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# December 12, 1963
# 1963-12-12 00:00:00
#
# None
#
# None
#
# 11 December 1963
# 1963-12-11 00:00:00
#
# None
#
# August 27, 1964
# 1964-08-27 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# February 4, 1966
# 1966-02-04 00:00:00
#
# June 29, 1966
# 1966-06-29 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# June 23, 1967
# 1967-06-23 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# December 24, 1968
# 1968-12-24 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# December 11, 1970
# 1970-12-11 00:00:00
#
# None
#
# None
#
# None
#
# October 7, 1971
# 1971-10-07 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# December 17, 1976
# 1976-12-17 00:00:00
#
# Release dates
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# Release dates
# None
#
# December 18, 1979
# 1979-12-18 00:00:00
#
# None
#
# April 17, 1980
# 1980-04-17 00:00:00
#
# None
#
# None
#
# December 6, 1980
# 1980-12-06 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# Release dates
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# 3 October 1990
# 1990-10-03 00:00:00
#
# None
#
# None
#
# September 29, 1991
# 1991-09-29 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# November 5, 1994
# 1994-11-05 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# June 10, 1995
# 1995-06-10 00:00:00
#
# None
#
# None
#
# None
#
# January 22, 1995
# 1995-01-22 00:00:00
#
# November 19, 1995
# 1995-11-19 00:00:00
#
# None
#
# None
#
# None
#
# April 12, 1996
# 1996-04-12 00:00:00
#
# June 19, 1996
# 1996-06-19 00:00:00
#
# None
#
# None
#
# None
#
# November 18, 1996
# 1996-11-18 00:00:00
#
# None
#
# March 7, 1997
# 1997-03-07 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# November 16, 1997
# 1997-11-16 00:00:00
#
# None
#
# None
#
# None
#
# June 5, 1998
# 1998-06-05 00:00:00
#
# July 20, 1998
# 1998-07-20 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# November 14, 1998
# 1998-11-14 00:00:00
#
# None
#
# None
#
# None
#
# Release dates
# None
#
# June 12, 1999
# 1999-06-12 00:00:00
#
# None
#
# None
#
# May 21, 1999
# 1999-05-21 00:00:00
#
# None
#
# November 13, 1999
# 1999-11-13 00:00:00
#
# December 17, 1999
# 1999-12-17 00:00:00
#
# None
#
# None
#
# None
#
# May 13, 2000
# 2000-05-13 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# December 10, 2000
# 2000-12-10 00:00:00
#
# February 10, 2001
# 2001-02-10 00:00:00
#
# None
#
# June 3, 2001
# 2001-06-03 00:00:00
#
# July 29, 2001
# 2001-07-29 00:00:00
#
# None
#
# October 28, 2001
# 2001-10-28 00:00:00
#
# None
#
# None
#
# February 10, 2002
# 2002-02-10 00:00:00
#
# None
#
# None
#
# None
#
# June 16, 2002
# 2002-06-16 00:00:00
#
# None
#
# July 21, 2002
# 2002-07-21 00:00:00
#
# None
#
# None
#
# October 23, 2002
# 2002-10-23 00:00:00
#
# November 6, 2002
# 2002-11-06 00:00:00
#
# None
#
# None
#
# None
#
# March 16, 2003
# 2003-03-16 00:00:00
#
# March 31, 2003
# 2003-03-31 00:00:00
#
# None
#
# None
#
# None
#
# May 18, 2003
# 2003-05-18 00:00:00
#
# June 28, 2003
# 2003-06-28 00:00:00
#
# August 4, 2003
# 2003-08-04 00:00:00
#
# None
#
# None
#
# October 20, 2003
# 2003-10-20 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# March 21, 2004
# 2004-03-21 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# October 24, 2004
# 2004-10-24 00:00:00
#
# None
#
# None
#
# None
#
# November 3, 2004
# 2004-11-03 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# May 10, 2005
# 2005-05-10 00:00:00
#
# None
#
# March 25, 2005
# 2005-03-25 00:00:00
#
# None
#
# None
#
# None
#
# October 30, 2005
# 2005-10-30 00:00:00
#
# 7 December 2005
# 2005-12-07 00:00:00
#
# None
#
# None
#
# None
#
# January 26, 2006
# 2006-01-26 00:00:00
#
# None
#
# None
#
# None
#
# May 26, 2006
# 2006-05-26 00:00:00
#
# June 23, 2006
# 2006-06-23 00:00:00
#
# June 16, 2006
# 2006-06-16 00:00:00
#
# None
#
# None
#
# October 13, 1993
# 1993-10-13 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# March 23, 2007
# 2007-03-23 00:00:00
#
# May 19, 2007
# 2007-05-19 00:00:00
#
# June 22, 2007
# 2007-06-22 00:00:00
#
# June 29, 2007
# 2007-06-29 00:00:00
#
# None
#
# None
#
# September 23, 2007
# 2007-09-23 00:00:00
#
# October 20, 2007
# 2007-10-20 00:00:00
#
# None
#
# None
#
# None
#
# May 7, 2008
# 2008-05-07 00:00:00
#
# June 23, 2008
# 2008-06-23 00:00:00
#
# None
#
# September 18, 2008
# 2008-09-18 00:00:00
#
# None
#
# October 17, 2008
# 2008-10-17 00:00:00
#
# 23 October 2008
# 2008-10-23 00:00:00
#
# None
#
# November 17, 2008
# 2008-11-17 00:00:00
#
# None
#
# None
#
# March 11, 2009
# 2009-03-11 00:00:00
#
# None
#
# 10 October 2007
# 2007-10-10 00:00:00
#
# April 24, 2009
# 2009-04-24 00:00:00
#
# May 13, 2009
# 2009-05-13 00:00:00
#
# None
#
# None
#
# None
#
# June 5, 2009
# 2009-06-05 00:00:00
#
# None
#
# November 3, 2009
# 2009-11-03 00:00:00
#
# None
#
# November 25, 2009
# 2009-11-25 00:00:00
#
# February 25, 2010
# 2010-02-25 00:00:00
#
# September 6, 2009
# 2009-09-06 00:00:00
#
# October 17, 2009
# 2009-10-17 00:00:00
#
# May 9, 2010
# 2010-05-09 00:00:00
#
# June 12, 2010
# 2010-06-12 00:00:00
#
# July 8, 2010
# 2010-07-08 00:00:00
#
# 26 October 2008
# 2008-10-26 00:00:00
#
# August 13, 2010
# 2010-08-13 00:00:00
#
# September 30, 2010
# 2010-09-30 00:00:00
#
# None
#
# November 14, 2010
# 2010-11-14 00:00:00
#
# November 30, 2010
# 2010-11-30 00:00:00
#
# None
#
# None
#
# None
#
# March 6, 2011
# 2011-03-06 00:00:00
#
# None
#
# April 22, 2011
# 2011-04-22 00:00:00
#
# None
#
# May 7, 2011
# 2011-05-07 00:00:00
#
# June 18, 2011
# 2011-06-18 00:00:00
#
# April 6, 2011
# 2011-04-06 00:00:00
#
# None
#
# November 4, 2011
# 2011-11-04 00:00:00
#
# None
#
# February 22, 2012
# 2012-02-22 00:00:00
#
# April 20, 2012
# 2012-04-20 00:00:00
#
# None
#
# June 10, 2012
# 2012-06-10 00:00:00
#
# None
#
# None
#
# September 20, 2012
# 2012-09-20 00:00:00
#
# August 16, 2012
# 2012-08-16 00:00:00
#
# October 29, 2012
# 2012-10-29 00:00:00
#
# February 14, 2013
# 2013-02-14 00:00:00
#
# 16 March 2011
# 2011-03-16 00:00:00
#
# June 5, 2013
# 2013-06-05 00:00:00
#
# June 22, 2013
# 2013-06-22 00:00:00
#
# August 2, 2013
# 2013-08-02 00:00:00
#
# None
#
# November 19, 2013
# 2013-11-19 00:00:00
#
# October 20, 2013
# 2013-10-20 00:00:00
#
# March 11, 2014
# 2014-03-11 00:00:00
#
# February 13, 2014
# 2014-02-13 00:00:00
#
# None
#
# May 6, 2014
# 2014-05-06 00:00:00
#
# May 28, 2014
# 2014-05-28 00:00:00
#
# July 15, 2014
# 2014-07-15 00:00:00
#
# None
#
# October 6, 2014
# 2014-10-06 00:00:00
#
# October 23, 2014
# 2014-10-23 00:00:00
#
# December 8, 2014
# 2014-12-08 00:00:00
#
# February 9, 2015
# 2015-02-09 00:00:00
#
# December 12, 2014
# 2014-12-12 00:00:00
#
# February 13, 2015
# 2015-02-13 00:00:00
#
# None
#
# May 9, 2015
# 2015-05-09 00:00:00
#
# May 18, 2015
# 2015-05-18 00:00:00
#
# None
#
# November 10, 2015
# 2015-11-10 00:00:00
#
# January 25, 2016
# 2016-01-25 00:00:00
#
# February 13, 2016
# 2016-02-13 00:00:00
#
# April 4, 2016
# 2016-04-04 00:00:00
#
# April 23, 2016
# 2016-04-23 00:00:00
#
# May 10, 2016
# 2016-05-10 00:00:00
#
# June 8, 2016
# 2016-06-08 00:00:00
#
# May 14, 2016
# 2016-05-14 00:00:00
#
# August 8, 2016
# 2016-08-08 00:00:00
#
# September 10, 2016
# 2016-09-10 00:00:00
#
# November 14, 2016
# 2016-11-14 00:00:00
#
# 21 December 2016
# 2016-12-21 00:00:00
#
# 26 January 2005
# 2005-01-26 00:00:00
#
# February 23, 2017
# 2017-02-23 00:00:00
#
# August 12, 2016
# 2016-08-12 00:00:00
#
# May 11, 2017
# 2017-05-11 00:00:00
#
# May 23, 2017
# 2017-05-23 00:00:00
#
# None
#
# None
#
# None
#
# October 20, 2017
# 2017-10-20 00:00:00
#
# February 26, 2018
# 2018-02-26 00:00:00
#
# June 5, 2018
# 2018-06-05 00:00:00
#
# July 30, 2018
# 2018-07-30 00:00:00
#
# October 29, 2018
# 2018-10-29 00:00:00
#
# November 5, 2018
# 2018-11-05 00:00:00
#
# November 29, 2018
# 2018-11-29 00:00:00
#
# March 11, 2019
# 2019-03-11 00:00:00
#
# None
#
# May 8, 2019
# 2019-05-08 00:00:00
#
# June 11, 2019
# 2019-06-11 00:00:00
#
# July 9, 2019
# 2019-07-09 00:00:00
#
# None
#
# None
#
# None
#
# November 7, 2019
# 2019-11-07 00:00:00
#
# None
#
# January 25, 2020
# 2020-01-25 00:00:00
#
# February 21, 2020
# 2020-02-21 00:00:00
#
# None
#
# March 28, 2018
# 2018-03-28 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# None
#
# March 9, 2020
# 2020-03-09 00:00:00
#
# None
#
# None
#
# October 11, 2020
# 2020-10-11 00:00:00
#
# December 24, 2020
# 2020-12-24 00:00:00
#
# None
#
# None
#
# May 18, 2021
# 2021-05-18 00:00:00
#
# June 13, 2021
# 2021-06-13 00:00:00
#
# July 24, 2021
# 2021-07-24 00:00:00
#
# November 3, 2021
# 2021-11-03 00:00:00
#
# None
#
# None
#
# None
#
# March 1, 2022
# 2022-03-01 00:00:00
#
# March 16, 2022
# 2022-03-16 00:00:00
#
# March 15, 2022
# 2022-03-15 00:00:00
#
# None
#
# May 16, 2022
# 2022-05-16 00:00:00
#
# May 23, 2022
# 2022-05-23 00:00:00
#
# June 8, 2022
# 2022-06-08 00:00:00
#
# None
#
# None
#
# None
#
# November 16, 2022
# 2022-11-16 00:00:00
#
# November 15, 2022
# 2022-11-15 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# None
#
# May 8, 2023
# 2023-05-08 00:00:00
#
# May 27, 2023
# 2023-05-27 00:00:00
#
# May 18, 2023
# 2023-05-18 00:00:00
#
# None
#
# None
#
# None
#
# May 18, 2015
# 2015-05-18 00:00:00
#
# July 9, 2019
# 2019-07-09 00:00:00
#
# None
#
# October 6, 2014
# 2014-10-06 00:00:00
#
# August 9, 1942
# 1942-08-09 00:00:00
#
# None
#
# None
#
# None
#
# June 19, 1996
# 1996-06-19 00:00:00
#
# None
#
# None
#
# November 14, 2016
# 2016-11-14 00:00:00
#
# None
#
# None
#
# None
#
# None
#
# December 11, 1970
# 1970-12-11 00:00:00
#
# None
#
# None
#
# Release dates
# None
#
# None
#
# February 13, 2016
# 2016-02-13 00:00:00

# %%
for movie in data:
    movie['Release date in datetime'] = date_conversion(movie.get('Release dates', 'N/A'))
# Out:
# December 21, 1937
# February 7, 1940
# October 23, 1941
# August 9, 1942
# August 24, 1942
# December 21, 1944
# April 20, 1946
# November 12, 1946
# November 29, 1948
# February 15, 1950
# June 22, 1950
# July 26, 1951
# 13 March 1952
# 26 October 1953
# June 24, 1959
# June 1960
# November 14, 1962
# December 12, 1963
# 11 December 1963
# August 27, 1964
# February 4, 1966
# June 29, 1966
# June 23, 1967
# December 24, 1968
# December 11, 1970
# October 7, 1971
# December 17, 1976
# Release dates
# Release dates
# December 18, 1979
# April 17, 1980
# December 6, 1980
# Release dates
# 3 October 1990
# September 29, 1991
# November 5, 1994
# June 10, 1995
# January 22, 1995
# November 19, 1995
# April 12, 1996
# June 19, 1996
# November 18, 1996
# March 7, 1997
# November 16, 1997
# June 5, 1998
# July 20, 1998
# November 14, 1998
# Release dates
# June 12, 1999
# May 21, 1999
# November 13, 1999
# December 17, 1999
# May 13, 2000
# December 10, 2000
# February 10, 2001
# June 3, 2001
# July 29, 2001
# October 28, 2001
# February 10, 2002
# June 16, 2002
# July 21, 2002
# October 23, 2002
# November 6, 2002
# March 16, 2003
# March 31, 2003
# May 18, 2003
# June 28, 2003
# August 4, 2003
# October 20, 2003
# March 21, 2004
# October 24, 2004
# November 3, 2004
# May 10, 2005
# March 25, 2005
# October 30, 2005
# 7 December 2005
# January 26, 2006
# May 26, 2006
# June 23, 2006
# June 16, 2006
# October 13, 1993
# March 23, 2007
# May 19, 2007
# June 22, 2007
# June 29, 2007
# September 23, 2007
# October 20, 2007
# May 7, 2008
# June 23, 2008
# September 18, 2008
# October 17, 2008
# 23 October 2008
# November 17, 2008
# March 11, 2009
# 10 October 2007
# April 24, 2009
# May 13, 2009
# June 5, 2009
# November 3, 2009
# November 25, 2009
# February 25, 2010
# September 6, 2009
# October 17, 2009
# May 9, 2010
# June 12, 2010
# July 8, 2010
# 26 October 2008
# August 13, 2010
# September 30, 2010
# November 14, 2010
# November 30, 2010
# March 6, 2011
# April 22, 2011
# May 7, 2011
# June 18, 2011
# April 6, 2011
# November 4, 2011
# February 22, 2012
# April 20, 2012
# June 10, 2012
# September 20, 2012
# August 16, 2012
# October 29, 2012
# February 14, 2013
# 16 March 2011
# June 5, 2013
# June 22, 2013
# August 2, 2013
# November 19, 2013
# October 20, 2013
# March 11, 2014
# February 13, 2014
# May 6, 2014
# May 28, 2014
# July 15, 2014
# October 6, 2014
# October 23, 2014
# December 8, 2014
# February 9, 2015
# December 12, 2014
# February 13, 2015
# May 9, 2015
# May 18, 2015
# November 10, 2015
# January 25, 2016
# February 13, 2016
# April 4, 2016
# April 23, 2016
# May 10, 2016
# June 8, 2016
# May 14, 2016
# August 8, 2016
# September 10, 2016
# November 14, 2016
# 21 December 2016
# 26 January 2005
# February 23, 2017
# August 12, 2016
# May 11, 2017
# May 23, 2017
# October 20, 2017
# February 26, 2018
# June 5, 2018
# July 30, 2018
# October 29, 2018
# November 5, 2018
# November 29, 2018
# March 11, 2019
# May 8, 2019
# June 11, 2019
# July 9, 2019
# November 7, 2019
# January 25, 2020
# February 21, 2020
# March 28, 2018
# March 9, 2020
# October 11, 2020
# December 24, 2020
# May 18, 2021
# June 13, 2021
# July 24, 2021
# November 3, 2021
# March 1, 2022
# March 16, 2022
# March 15, 2022
# May 16, 2022
# May 23, 2022
# June 8, 2022
# November 16, 2022
# November 15, 2022
# May 8, 2023
# May 27, 2023
# May 18, 2023
# May 18, 2015
# July 9, 2019
# October 6, 2014
# August 9, 1942
# June 19, 1996
# November 14, 2016
# December 11, 1970
# Release dates
# February 13, 2016

# %% [markdown]
# save data as json and csv and pickle

# %%
import pickle

with open('disney_movie_cleaned_data.pickle', 'wb') as f:
    pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
disney_movies_copy = [movie.copy() for movie in data]

for movie in disney_movies_copy:  # converting datetime to str for saving in json
    if movie['Release date in datetime']:
        movie['Release date in datetime'] = movie['Release date in datetime'].strftime('%B %d, %Y')
    else: 
        movie['Release date in datetime'] = None

import json

with open('final_data.json', 'w') as fp:
    json.dump(disney_movies_copy, fp)

# %%
import pandas as pd

df = pd.DataFrame(data)
df.to_csv('final_dataset.csv')
